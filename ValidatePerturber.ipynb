# %%
from radcam import Perturber
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

grey = np.full((64, 64), 150, dtype=np.uint8)
img = Image.fromarray(grey).convert("L")

# plt shows grey as purple and white as yellow.
plt.figure()
plt.imshow(img)

# %%
perturber = Perturber(grey, (32, 32))
perturbed = perturber.perturb()

# %%
import matplotlib.pyplot as plt

for img in perturbed:
    plt.figure(figsize=(2,2))
    plt.imshow(Image.fromarray(img).convert("L"))

# %%
rgb = np.zeros((64, 64, 3), dtype=np.uint8)
rgb[:,:] = [64, 200, 64]
img = Image.fromarray(rgb).convert("RGB")
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7EFF80488E90>

# %%
perturber = Perturber(rgb, (32, 32))
perturbed = perturber.perturb()

# %%
for img in perturbed:
    plt.figure(figsize=(2,2))
    plt.imshow(Image.fromarray(img))

# %%
from radcam.perturber import Perturbation

perturber = Perturber(rgb, (32, 32))
perturbed = perturber.perturb(perturbation_type=Perturbation.white)
for img in perturbed:
    plt.figure(figsize=(2,2))
    plt.imshow(Image.fromarray(img))

# %%
perturbed = perturber.perturb(perturbation_type=Perturbation.noise)
for img in perturbed:
    plt.figure(figsize=(2,2))
    plt.imshow(Image.fromarray(img))

# %%
perturbed = perturber.perturb(perturbation_type=Perturbation.gaussian)
for img in perturbed:
    plt.figure(figsize=(2,2))
    plt.imshow(Image.fromarray(img))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-73d9aeffda28> in <module>
#       1 perturbed = perturber.perturb(perturbation_type=Perturbation.gaussian)
# ----> 2 for img in perturbed:
#       3     plt.figure(figsize=(2,2))
#       4     plt.imshow(Image.fromarray(img))
#
# TypeError: 'NoneType' object is not iterable

# %%
from scipy.ndimage.filters import gaussian_filter
img = gaussian_filter(perturbed[1], 2)

# %%
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7EFF7E767A90>
